# %% [markdown]
# <a href="https://colab.research.google.com/github/hyunil-cho/ml_practice/blob/main/k_means.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.preprocessing import scale
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd



iris = load_iris()
X = iris.data
iris_df = pd.DataFrame(X, columns=iris.feature_names)

iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit_transform(iris_df )
kmeans.fit(iris_df)
target= iris.target

# %%
kmeans.fit_transform(iris_df )
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    cluster  target
# 0        1       0
# 1        1       0
# 2        1       0
# 3        1       0
# 4        1       0

# %%
iris_result = iris_df.groupby(['target','cluster'])['sepal width (cm)'].count()
iris_result
# Out:
# target  cluster
# 0       1          50
# 1       0          47
#         2           3
# 2       0          14
#         2          36
# Name: sepal width (cm), dtype: int64
